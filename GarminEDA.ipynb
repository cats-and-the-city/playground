# %% [markdown]
# # Research on datasets for Assignment B

# %% [markdown]
# ### B1: Video:
#
# The first part of the final project is an 1 minute movie, which should explain the central idea/concept that you will investigate in your final project. You're making the movie so that the TAs and I can give you feedback, and so that other groups can steal your ideas (and you can steal ideas from them). The movie must contain the following
#
# - An explanation of the central idea behind your final project, e.g. think about questions such as
#     - What is the idea?
#     - Which datasets do you need to explore the idea?,
#     - Why is it interesting?
#
# - A mock up of the visualization that you wish to build. (Anything is fine here. Pen and paper, MS Paint, Inkscape, D3, Midjourney (or any other LLM), anything is OK).
#
#
# - Make sure you answer the questions
#     - What genre is it? (for Genres, see section 4.3 of the Segel and Heer paper)
#     - Why is that genre right for telling the story you want to communicate with the data
#     - A walk-through of your preliminary data-analysis, addressing
#         - What is the total size of your data? (MB, number of rows, number of variables, etc)
#         - What are other properties? (What is the date range? Is is it geo-data?, then a quick plot of locations, etc.)
#
# Show the fundamental distributions of the data (similar to the work we did on SF crime data)
# But other than that, there are no constraints. And we do appreciate funny/inventive/beautiful movies, although the academic content is most important. Note that we'll display the movie to the entire class.
#
# (The maximum length is 1 minutes, but its OK if the movie is shorter.)

# %% [markdown]
# ## Garmin dataset

# %%
# %matplotlib inline
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from glob import glob
import json
import matplotlib.pyplot as plt
import seaborn as sns
garmin_base_dir = "../files/Garmin_20241403"

# %%
# !ls -R {garmin_base_dir}
# Out:
# DI_CONNECT            IT_DEVICE_AND_CONTENT customer_data
#
# ../files/Garmin_20241403/DI_CONNECT:
# DI-ATP                    DI-Connect-Routing        DI-Connect-Wellness
# DI-Connect-Aggregator     DI-Connect-Social         DI-GOLF
# DI-Connect-Fitness        DI-Connect-Uploaded-Files
# DI-Connect-Metrics        DI-Connect-User
#
# ../files/Garmin_20241403/DI_CONNECT/DI-ATP:
# Garmin_Coach_Pause_History.json
#
# ../files/Garmin_20241403/DI_CONNECT/DI-Connect-Aggregator:
# HydrationLogFile_2020-05-14_2020-08-22.json
# HydrationLogFile_2020-08-22_2020-11-30.json
# HydrationLogFile_2020-11-30_2021-03-10.json
# HydrationLogFile_2021-03-10_2021-06-18.json
# HydrationLogFile_2021-06-18_2021-09-26.json
# HydrationLogFile_2021-09-26_2022-01-04.json
# HydrationLogFile_2022-01-04_2022-04-14.json
# HydrationLogFile_2022-04-14_2022-07-23.json
# HydrationLogFile_2022-07-23_2022-10-31.json
# HydrationLogFile_2022-10-31_2023-02-08.json
# HydrationLogFile_2023-02-08_2023-05-19.json
# HydrationLogFile_2023-05-19_2023-08-27.json
# HydrationLogFile_2023-08-27_2023-12-05.json
# HydrationLogFile_2023-12-05_2024-03-14.json
# UDSFile_2005-11-10_2006-02-18.json
# UDSFile_2011-05-03_2011-08-11.json
# UDSFile_2011-08-11_2011-11-19.json
# UDSFile_2012-09-14_2012-12-23.json
# UDSFile_2013-07-11_2013-10-19.json
# UDSFile_2014-01-27_2014-05-07.json
# UDSFile_2014-05-07_2014-08-15.json
# UDSFile_2014-08-15_2014-11-23.json
# UDSFile_2020-05-15_2020-08-23.json
# UDSFile_2020-08-23_2020-12-01.json
# UDSFile_2020-12-01_2021-03-11.json
# 2023-08-28_2023-12-06_86607424_sleepData.json
# 2023-12-06_2024-03-15_86607424_sleepData.json
# 86607424_DailyMenstrualLogs.json
# 86607424_MenstrualCycles.json
# 86607424_bioMetrics_latest.json
# 86607424_heartRateZones.json
# 86607424_userBioMetricProfileData.json
# 86607424_userBioMetrics.json
#
# ../files/Garmin_20241403/DI_CONNECT/DI-GOLF:
# Golf-CLUB.json        Golf-COURSE.json      Golf-SIM_SESSION.json
# Golf-CLUB_TYPES.json  Golf-SCORECARD.json   Golf-SWING.json
# Golf-COMMENTS.json    Golf-SHOT.json
#
# ../files/Garmin_20241403/IT_DEVICE_AND_CONTENT:
# devicesandcontent.json
#
# ../files/Garmin_20241403/customer_data:
# customer.json

# %%
# %matplotlib inline
import pandas as pd
import os
import json
from IPython.display import display

# The corrected path
garmin_base_dir = "../files/Garmin_20241403"
di_connect_path = os.path.join(garmin_base_dir, "DI_CONNECT")  # Correcting the folder name

# Adjusting the function to account for JSON structures with multiple entries
def find_and_dance_json(path):
    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith('.json'):
                full_path = os.path.join(root, file)
                with open(full_path, 'r') as f:
                    data = json.load(f)
                
                # Checking if the JSON is a list of dictionaries
                if isinstance(data, list) and all(isinstance(item, dict) for item in data):
                    df = pd.DataFrame(data)
                elif isinstance(data, dict):
                    # For a single dictionary, we still convert it into a DataFrame
                    df = pd.DataFrame([data])
                else:
                    # If the structure is different, we might need to adjust the approach
                    print(f"Unexpected JSON structure in {file}")
                    continue
                
                # Displaying the DataFrame
                print(f"DataFrame for {os.path.basename(file)}:")
                display(df.head())

# Time for the adjusted dance!
find_and_dance_json(di_connect_path)
# Out:
# DataFrame for HydrationLogFile_2021-03-10_2021-06-18.json:
#    userProfilePK calendarDate    persistedTimestampGMT         timestampLocal  \
# 0       86607424   2021-03-10  2021-03-10T06:44:14.763  2021-03-10T06:54:34.0
# 1       86607424   2021-03-10  2021-03-10T14:51:04.953  2021-03-10T15:29:03.0
# 2       86607424   2021-03-11  2021-03-11T07:22:16.819  2021-03-11T07:35:28.0
# 3       86607424   2021-03-11  2021-03-11T14:14:49.302  2021-03-11T14:31:19.0
# 4       86607424   2021-03-12  2021-03-12T06:48:59.294  2021-03-12T07:18:24.0
#
#    hydrationSource  valueInML  activityId  capped  estimatedSweatLossInML  \
# 0  GARMIN_ACTIVITY        0.0  6404861717   False                   288.0
# 1  GARMIN_ACTIVITY        0.0  6406831415   False                    88.0
# 2  GARMIN_ACTIVITY        0.0  6410406388   False                   278.0
# 3  GARMIN_ACTIVITY        0.0  6411985940   False                   184.0
# 4  GARMIN_ACTIVITY        0.0  6415357653   False                   210.0
#
#       duration
# 0  2953.853027
# 1  1256.212036
# 2  2786.937988
# 3  2488.120117
# 4  1773.087036
# DataFrame for UDSFile_2012-09-14_2012-12-23.json:
#    userProfilePK calendarDate                              uuid  \
# 0       86607424   2012-10-07  88ef2e8dabf2426a981c252fd6358288
# 1       86607424   2012-10-23  0f78673ba26b4e75a9d49102696e3563
# 2       86607424   2012-10-30  6302f22757214fd0983b47e13d27e133
# 3       86607424   2012-11-06  faf6cef6a2a341948c8efaeff255e969
# 4       86607424   2012-11-13  a69e3261b68c485eb20a4de92511fde1
#
#    durationInMilliseconds  totalKilocalories  activeKilocalories  \
# 0                       
ityId  capped  estimatedSweatLossInML  \
# 0  GARMIN_ACTIVITY        0.0  11890501861   False                   349.0
# 1  GARMIN_ACTIVITY        0.0  11897664811   False                   290.0
# 2  GARMIN_ACTIVITY        0.0  11898831810   False                   459.0
# 3  GARMIN_ACTIVITY        0.0  11904990911   False                   218.0
# 4  GARMIN_ACTIVITY        0.0  11906757813   False                   267.0
#
#       duration                                              uuid
# 0  3636.394043  {'uuid': '22880e7a-8aa5-4c2a-830a-dad5959137ca'}
# 1  3090.362061  {'uuid': '02d4d759-697a-427c-b8b4-bdeb8c66bb25'}
# 2  4159.275879  {'uuid': 'c4c72fbd-7480-48a8-a86e-c722745cd967'}
# 3  2144.062988  {'uuid': '973dc6ed-58bc-46ec-9957-8830e38d7ed8'}
# 4  2299.772949  {'uuid': '3d852f0d-ec61-490f-b281-23c3bfc779b1'}
# DataFrame for UDSFile_2022-11-01_2023-02-09.json:
#    userProfilePK calendarDate                              uuid  \
# 0       86607424   2022-11-01  bc12f9d6a46846968aa244c6fdbef2bf
# 1       86607424   2022-11-02  22f750e80c9b4033aa817b7bb608981b
# 2       86607424   2022-11-03  1a4d5f580deb4088b0668635a166b0bd
# 3       86607424   2022-11-04  fbe7a96deeb5474eb4ca55ed678f001f
# 4       86607424   2022-11-05  e6b0d05086124890bb571fd585a0b1a5
#
#    durationInMilliseconds  totalKilocalories  activeKilocalories  \
# 0                86400000             3223.0              1706.0
# 1                86400000             2686.0              1169.0
# 2                86400000             2261.0               744.0
# 3                86400000             2999.0              1482.0
# 4                86400000             2455.0               938.0
#
#    bmrKilocalories  wellnessKilocalories  remainingKilocalories  \
# 0           1517.0                3223.0                 3223.0
# 1           1517.0                2686.0                 2686.0
# 2           1517.0                2261.0                 2261.0
# 3           1517.0                2999.0                 2999.0
# 4           1517.0                2455.0                 2455.0
#
#    wellnessTotalKilocalories  ...  includesAllDayPulseOx  \
# 0                     3223.0  ...                  False
# 1                     2686.0  ...                  False
# 2                     2261.0  ...                  False
# 3                     2999.0  ...                  False
# 4                     2455.0  ...                  False
#
#    includesSleepPulseOx  source  \
# 0                 False       0
# 1                 False       0
# 2                 False       0
# 3                 False       0
# 4                 False       0
#
#                                         allDayStress  \
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...
#
#                                          bodyBattery  minAvgHeartRate  \
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...               54
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...               57
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...               55
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...               56
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...               53
#
#    maxAvgHeartRate   version  \
# 0              167  75360003
# 1              145  31740002
# 2              161  57960002
# 3              148  75060003
# 4              135  69660002
#
#                                            hydration  \
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...
#
#                                          respiration
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...
#
# [5 rows x 49 columns]
# DataFrame for UDSFile_2023-08-28_2023-12-06.json:
#    userProfilePK calendarDate                              uuid  \
# 0       86607424   2023-08-28  fae4429c96464f9eb8971cebbf9887ed
# 1       86607424   2023-08-29  c9b51cafdbd24e7daf74ab3a2b3a29f3
# 2       86607424   2023-08-30  951b6ce5f63947eba6a8ee4586966f91
# 3       86607424   2023-08-31  66b079bd5dc24247b5875b4c444b20af
# 4       86607424   2023-09-01  ee2774aa2d3a4d14909751ecc567496d
#
#    durationInMilliseconds  totalKilocalories  activeKilocalories  \
# 0                86400000             1835.0               371.0
# 1                86400000             2289.0               825.0
# 2                86400000             1853.0               389.0
# 3                86400000             2344.0               880.0
# 4                86400000             1909.0               445.0
#
#    bmrKilocalories  wellnessKilocalories  remainingKilocalories  \
# 0           1464.0                1835.0                 1835.0
# 1           1464.0                2289.0                 2289.0
# 2           1464.0                1853.0                 1853.0
# 3           1464.0                2344.0                 2344.0
# 4           1464.0                1909.0                 1909.0
#
#    wellnessTotalKilocalories  ...  includesAllDayPulseOx  \
# 0                     1835.0  ...                  False
# 1                     2289.0  ...                  False
# 2                     1853.0  ...                  False
# 3                     2344.0  ...                  False
# 4                     1909.0  ...                  False
#
#    includesSleepPulseOx  source  \
# 0                 False       0
# 1                 False       0
# 2                 False       0
# 3                 False       0
# 4                 False       0
#
#                                         allDayStress  \
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...
#
#                                
json:
#    userProfilePK calendarDate                              uuid  \
# 0       86607424   2021-03-11  8008b6490954421d8179ad2acc86a941
# 1       86607424   2021-03-12  fb149d7e3c2e4eea91944a69b742da3d
# 2       86607424   2021-03-13  a8ce7714cdeb41dea992ba23e69e86f8
# 3       86607424   2021-03-14  b5eac2adc2724f07be80c767d3110da4
# 4       86607424   2021-03-15  11d7674dcc3345d1a35b86c21983b304
#
#    durationInMilliseconds  totalKilocalories  activeKilocalories  \
# 0                86400000             2201.0               674.0
# 1                86400000             2498.0               971.0
# 2                86400000             2949.0              1422.0
# 3                86400000             1930.0               403.0
# 4                86400000             2443.0               916.0
#
#    bmrKilocalories  wellnessKilocalories  consumedKilocalories  \
# 0           1527.0                2201.0                   0.0
# 1           1527.0                2498.0                   NaN
# 2           1527.0                2949.0                   0.0
# 3           1527.0                1930.0                   0.0
# 4           1527.0                2443.0                   NaN
#
#    remainingKilocalories  ...  minAvgHeartRate  maxAvgHeartRate   version  \
# 0                 2201.0  ...               57              148  57240003
# 1                 2498.0  ...               54              146  59940005
# 2                 2949.0  ...               58              153  52920004
# 3                 1930.0  ...               55              113  71880003
# 4                 2443.0  ...               57              148  69180004
#
#    averageSpo2Value  lowestSpo2Value  latestSpo2Value  \
# 0              95.0               85               95
# 1              96.0               90               97
# 2              97.0               92               97
# 3              97.0               92               96
# 4              97.0               91               96
#
#    latestSpo2ValueReadingTimeGmt latestSpo2ValueReadingTimeLocal  \
# 0          2021-03-11T23:00:00.0           2021-03-12T00:00:00.0
# 1          2021-03-12T23:00:00.0           2021-03-13T00:00:00.0
# 2          2021-03-13T23:00:00.0           2021-03-14T00:00:00.0
# 3          2021-03-14T22:58:00.0           2021-03-14T23:58:00.0
# 4          2021-03-15T23:00:00.0           2021-03-16T00:00:00.0
#
#                                            hydration  \
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...
#
#                                          respiration
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...
#
# [5 rows x 54 columns]
# DataFrame for UDSFile_2022-04-15_2022-07-24.json:
#    userProfilePK calendarDate                              uuid  \
# 0       86607424   2022-04-15  1bafe4cc97d744febbf2e469db8d901d
# 1       86607424   2022-04-16  f819e07ab35a4332988f10f8b28555ca
# 2       86607424   2022-04-17  b51efc89b1904a71b01390c72aaa4157
# 3       86607424   2022-04-18  6a5c024e044943229388dab8e5da5ae4
# 4       86607424   2022-04-19  8addbd8fc0484f6dad004d8cdaafd775
#
#    durationInMilliseconds  totalKilocalories  activeKilocalories  \
# 0                86400000             2573.0              1056.0
# 1                86400000             3364.0              1847.0
# 2                86400000             3128.0              1611.0
# 3                86400000             2642.0              1125.0
# 4                86400000             3025.0              1508.0
#
#    bmrKilocalories  wellnessKilocalories  remainingKilocalories  \
# 0           1517.0                2573.0                 2573.0
# 1           1517.0                3364.0                 3364.0
# 2           1517.0                3128.0                 3128.0
# 3           1517.0                2642.0                 2642.0
# 4           1517.0                3025.0                 3025.0
#
#    wellnessTotalKilocalories  ...  includesAllDayPulseOx  \
# 0                     2573.0  ...                  False
# 1                     3364.0  ...                  False
# 2                     3128.0  ...                  False
# 3                     2642.0  ...                  False
# 4                     3025.0  ...                  False
#
#    includesSleepPulseOx  source  \
# 0                 False       0
# 1                 False       0
# 2                 False       0
# 3                 False       0
# 4                 False       0
#
#                                         allDayStress  \
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...
#
#                                          bodyBattery  minAvgHeartRate  \
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...               57
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...               59
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...               60
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...               58
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...               54
#
#    maxAvgHeartRate   version  \
# 0              144  42240002
# 1              153  70320002
# 2              147  66960002
# 3              154  65040002
# 4              152  61260003
#
#                                            hydration  \
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...
#
#                                          respiration
# 0  {'userProfilePK': 86607424, 'calendarDate': '2...
# 1  {'userProfilePK': 86607424, 'calendarDate': '2...
# 2  {'userProfilePK': 86607424, 'calendarDate': '2...
# 3  {'userProfilePK': 86607424, 'calendarDate': '2...
# 4  {'userProfilePK': 86607424, 'calendarDate': '2...
#
# [5 rows x 49 columns]
# DataFrame for UDSFile_2023-12-06_2024-03-15.json:
# ...
#
#    fertileWindowStart  fertileWindowLength status          reportTimestamp  \
# 0                10.0                  7.0   PAST    2020-07-27T00:00:00.0
# 1                 9.0                  0.0   PAST  2020-07-27T12:05:03.640
# 2                10.0                  0.0   PAST  2020-10-30T06:40:43.844
# 3                10.0                  0.0   PAST    2020-11-29T08:10:20.0
# 4                 8.0                  0.0   PAST    2020-11-29T08:10:20.0
#
#    hasLoggedOvulationDay  initialPredictedPeriodLength  \
# 0                  False                           4.0
# 1                  False                           4.0
# 2                  False                           4.0
# 3                  False                           4.0
# 4                  False                           4.0
#
#    initialPredictedCycleLength          createTimestamp cycleType  \
# 0                         25.0  2020-07-02T22:43:05.239   REGULAR
# 1                         28.0  2020-07-27T12:05:03.640   REGULAR
# 2                         28.0  2020-08-20T17:09:24.265   REGULAR
# 3                         28.0  2020-09-18T06:13:48.736   REGULAR
# 4                         24.0  2020-10-25T20:34:32.958   REGULAR
#
#    applicableMenstrualCycleLength  applicablePeriodLength
# 0                              27                       4
# 1                              26                       4
# 2                              27                       4
# 3                              27                       5
# 4                              25                       4
# DataFrame for 2020-12-01_2021-03-11_86607424_sleepData.json:
#   sleepStartTimestampGMT   sleepEndTimestampGMT calendarDate  \
# 0  2020-11-30T21:30:00.0  2020-12-01T04:24:00.0   2020-12-01
# 1  2020-12-01T21:13:00.0  2020-12-02T04:29:00.0   2020-12-02
# 2  2020-12-02T21:37:00.0  2020-12-03T04:22:00.0   2020-12-03
# 3  2020-12-03T21:02:00.0  2020-12-04T04:25:00.0   2020-12-04
# 4  2020-12-04T23:06:00.0  2020-12-05T04:42:00.0   2020-12-05
#
#   sleepWindowConfirmationType  deepSleepSeconds  lightSleepSeconds  \
# 0          ENHANCED_CONFIRMED              3540              17160
# 1                   OFF_WRIST                 0                  0
# 2          ENHANCED_CONFIRMED              6360              12420
# 3          ENHANCED_CONFIRMED              5760              17280
# 4          ENHANCED_CONFIRMED              4560               9060
#
#    remSleepSeconds  awakeSleepSeconds  unmeasurableSeconds  \
# 0           3360.0                780                    0
# 1              NaN                  0                    0
# 2           5460.0                 60                    0
# 3           3360.0                180                    0
# 4           6540.0                  0                    0
#
#                                     spo2SleepSummary  averageRespiration  \
# 0  {'userProfilePk': 86607424, 'deviceId': 333492...                16.0
# 1  {'userProfilePk': 86607424, 'deviceId': 333492...                 NaN
# 2  {'userProfilePk': 86607424, 'deviceId': 333492...                15.0
# 3  {'userProfilePk': 86607424, 'deviceId': 333492...                15.0
# 4  {'userProfilePk': 86607424, 'deviceId': 333492...                15.0
#
#    lowestRespiration  highestRespiration  retro
# 0               13.0                19.0  False
# 1                NaN                 NaN  False
# 2               12.0                19.0  False
# 3               12.0                19.0  False
# 4                9.0                18.0  False
# DataFrame for 86607424_heartRateZones.json:
#   trainingMethod  zone1Floor  zone2Floor  zone3Floor  zone4Floor  zone5Floor  \
# 0         HR_MAX          89         106         124         142         159
# 1         HR_MAX          88         106         123         141         158
#
#    maxHeartRateUsed  restingHrAutoUpdateUsed    sport changeState
# 0               177                    False  RUNNING   UNCHANGED
# 1               176                    False  CYCLING   UNCHANGED
# DataFrame for UserGoal_2020-03-12_2020-06-20.json:
#    userProfilePk userGoalCategory       userGoalType  \
# 0       86607424           MANUAL              STEPS
# 1       86607424           MANUAL     FLOORS_CLIMBED
# 2       86607424           MANUAL  INTENSITY_MINUTES
# 3       86607424           MANUAL          HYDRATION
#
#                   startDate goalValue                            updateDate  \
# 0  {'date': 'Jun 18, 2020'}   10000.0  {'date': 'Jun 18, 2020 12:00:00 AM'}
# 1  {'date': 'Jun 15, 2020'}      10.0   {'date': 'Jun 18, 2020 8:37:57 AM'}
# 2  {'date': 'Jun 15, 2020'}     180.0   {'date': 'Jul 16, 2020 8:32:14 AM'}
# 3  {'date': 'Jun 15, 2020'}    2129.0   {'date': 'Jun 18, 2020 8:37:58 AM'}
#
#                             createDate activityTypePk  \
# 0  {'date': 'Jun 18, 2020 8:37:57 AM'}            NaN
# 1  {'date': 'Jun 18, 2020 8:37:57 AM'}              9
# 2  {'date': 'Jun 18, 2020 8:37:57 AM'}              9
# 3  {'date': 'Jun 18, 2020 8:37:58 AM'}              9
#
#                     endDate
# 0                       NaN
# 1                       NaN
# 2  {'date': 'Jul 12, 2020'}
# 3                       NaN
# DataFrame for user_profile_suica.json:
# Empty DataFrame
# Columns: []
# Index: [0]
# DataFrame for user_reminders.json:
# Empty DataFrame
# Columns: []
# Index: []
# DataFrame for user_settings.json:
#   preferredLocale handedness contraception menstrualCycleType  avgCycleLength  \
# 0              da      RIGHT          NONE            REGULAR              25
#
#    avgPeriodLength  useFixedLocation postalCode
# 0                5             False          0
# DataFrame for UserGoal_2021-01-06_2021-04-16.json:
#    userProfilePk userGoalCategory  userGoalType                 startDate  \
# 0       86607424           MANUAL  WEIGHT_GRAMS  {'date': 'Apr 15, 2021'}
#
#   goalValue                           updateDate  \
# 0   57500.0  {'date': 'Apr 15, 2021 6:33:59 AM'}
#
#                             createDate activityTypePk
# 0  {'date': 'Apr 15, 2021 6:33:59 AM'}              9
# DataFrame for GoalsFile.json:
#                                          goalDTOList
# 0  [{'goalId': 38214711, 'goalTypeId': 1, 'goalSe...
# DataFrame for UserGoal_2020-06-20_2020-09-28.json:
#    userProfilePk userGoalCategory       userGoalType  \
# 0       86607424           MANUAL       WEIGHT_GRAMS
# 1       86607424     MYFITNESSPAL       NET_CALORIES
# 2       86607424           MANUAL  INTENSITY_MINUTES
#
#                   startDate                   endDate goalName goalValue  \
# 0  {'date': 'Jul 18, 2020'}  {'date': 'Apr 14, 2021'}            57000.0
# 1   {'date': 'Jul 4, 2020'}                       NaN      NaN    1220.0
# 2  {'date': 'Jul 13, 2020'}                       NaN      NaN     500.0
#
#                             updateDate                           createDate  \
# 0  {'date': 'Apr 15, 2021 6:33:59 AM'}  {'date': 'Jul 18, 2020 4:45:32 AM'}
# 1                                  NaN   {'date': 'Jul 4, 2020 5:43:09 PM'}
# 2  {'date': 'Jul 16, 2020 8:32:14 AM'}  {'date': 'Jul 16, 2020 8:32:14 AM'}
#
#   activityTypePk
# 0            NaN
# 1            NaN
# 2              9
# DataFrame for user_contact.json:
#   firstName lastName           emails         phones
# 0     Tomek     Otap  [Tomek@otap.dk]  [+4527282442]
# DataFrame for user_profile.json:
#         userName firstName lastName   emailAddress  gender   birthDate
# 0  lenka@otap.dk     Lenka     Otap  lenka@otap.dk  FEMALE  1976-08-31
# DataFrame for lenka@otap.dk-social-profile.json:
#           id  profileId                           displayName    fullName  \
# 0  380929572   86607424  36148ba7-5f51-469f-a7c3-952ab7118075  Lenka Otap
#
#         userName                               profileImageUrlLarge  \
# 0  lenka@otap.dk  https://s3.amazonaws.com/garmin-connect-prod/p...
#
#                                profileImageUrlMedium  \
# 0  https://s3.amazonaws.com/garmin-connect-prod/p...
#
#                                 profileImageUrlSmall       location  \
# 0  https://s3.amazonaws.com/garmin-connect-prod/p...  København, NV
#
#          favoriteActivityTypes  ...  nameApproved  makeGolfScorecardsPrivate  \
# 0  [running, cycling, walking]  ...          True                       True
#
#    allowGolfLiveScoring  allowGolfScoringByConnections userLevel userPoint  \
# 0                 False                           True         5       516
#
#          levelUpdateDate levelIsViewed     levelUpdateDateGMT userPro
# 0  2022-07-12T21:11:53.0         False  2022-07-12T21:11:53.0   False
#
# [1 rows x 47 columns]
# Unexpected JSON structure in lenka@otap.dk-likes.json
# DataFrame for Golf-CLUB_TYPES.json:
#   version        type                                               data  \
# 0      v1  CLUB_TYPES  [{'value': 0, 'name': 'Unknown', 'shaftLength'...
#
#                  preparedOn
# 0  2024-03-14T10:54:19.747Z
# DataFrame for Golf-COMMENTS.json:
#   version      type                preparedOn
# 0      v1  COMMENTS  2024-03-14T10:54:19.747Z
# DataFrame for Golf-SHOT.json:
#   version  type                preparedOn
# 0      v1  SHOT  2024-03-14T10:54:19.747Z
# DataFrame for Golf-CLUB.json:
#   version  type                                               data  \
# 0      v1  CLUB  [{'id': 301976761, 'clubTypeId': 1, 'shaftLeng...
#
#                  preparedOn
# 0  2024-03-14T10:54:19.747Z
# DataFrame for Golf-SWING.json:
#   version   type                preparedOn
# 0      v1  SWING  2024-03-14T10:54:19.747Z
# DataFrame for Golf-SIM_SESSION.json:
#   version         type                preparedOn
# 0      v1  SIM_SESSION  2024-03-14T10:54:19.747Z
# DataFrame for Golf-COURSE.json:
#   version    type                preparedOn
# 0      v1  COURSE  2024-03-14T10:54:18.830Z
# DataFrame for Golf-SCORECARD.json:
#   version       type                preparedOn
# 0      v1  SCORECARD  2024-03-14T10:54:18.830Z
# DataFrame for lenka@otap.dk_2002_summarizedActivities.json:
#                           summarizedActivitiesExport
# 0  [{'activityId': 7476364705, 'uuidMsb': 5801912...
# DataFrame for lenka@otap.dk_activityImages.json:
#                             imageId  activityId  sortOrder  \
# 0  ea8aaf6cbade48e89bcf608b0ee81726  6227340816          0
# 1  ea26689453a047f8b2bf1af66c1f4a46  6227340816          1
#
#                                                  url              photoDate
# 0  https://s3.amazonaws.com/di-user-export/92a44b...  2021-02-06T09:10:58.0
# 1  https://s3.amazonaws.com/di-user-export/92a44b...  2021-02-06T09:10:26.0
# DataFrame for lenka@otap.dk_3003_summarizedActivities.json:
#                           summarizedActivitiesExport
# 0  [{'activityId': 5189730299, 'uuidMsb': -405715...
# DataFrame for lenka@otap.dk_workout.json:
#                                          workoutList  \
# 0  [{'workoutId': 257087474, 'ownerId': 86607424,...
#
#                                  workoutScheduleList
# 0  [{'workoutScheduleId': 320720881, 'workoutId':...
# DataFrame for lenka@otap.dk_0_summarizedActivities.json:
#                           summarizedActivitiesExport
# 0  [{'activityId': 14400862658, 'uuidMsb': -12424...
# DataFrame for lenka@otap.dk_personalRecord.json:
#                                      personalRecords
# 0  [{'personalRecordId': 1656640469, 'activityId'...
# DataFrame for lenka@otap.dk_1001_summarizedActivities.json:
#                           summarizedActivitiesExport
# 0  [{'activityId': 9700953035, 'uuidMsb': 4181414...
# DataFrame for lenka@otap.dk_trainingPlan.json:
# Empty DataFrame
# Columns: []
# Index: [0]
# DataFrame for lenka@otap.dk_gear.json:
#                                             gearDTOS  \
# 0  [{'gearPk': 25362076, 'uuid': '006eaf4bfcd3454...
#
#                                     gearActivityDTOs  \
# 0  {'30641059': [{'gearPk': 30641059, 'activityId...
#
#                                 gearActivityTypeDTOS
# 0  [{'activityType': 'running', 'gearPk': 3218782...
# DataFrame for lenka@otap.dk_courses_1710413659308.json:
#                     courseName accessControl  elevationGainMeter  \
# 0         Kopi af Brøndby, syd        public               73.62
# 1  Mammutmarch 30km route 2022       private              244.31
# 2            MM 100 2022 Lenka       private              619.63
# 3             MM 55 2023 Lenka       private              405.76
# 4            MM 100 2023 Lenka       private              657.61
#
#    elevationLossMeter                                         startPoint  \
# 0               73.51  {'latitude': 55.65210342407227, 'longitude': 1...
# 1              244.31  {'latitude': 55.770299, 'longitude': 12.453361...
# 2              619.75  {'latitude': 55.847935, 'longitude': 12.571158...
# 3              403.68  {'latitude': 55.774839, 'longitude': 12.439693...
# 4              657.54  {'latitude': 55.847935, 'longitude': 12.571158...
#
#                                            geoPoints courseType  \
# 0  [{'latitude': 55.652103340253234, 'longitude':...    running
# 1  [{'latitude': 55.77029898762703, 'longitude': ...     hiking
# 2  [{'latitude': 55.84793494082987, 'longitude': ...     hiking
# 3  [{'latitude': 55.77483896166086, 'longitude': ...     hiking
# 4  [{'latitude': 55.84793494082987, 'longitude': ...     hiking
#
#    elapsedSeconds  speedMeterPerSecond             createDate  \
# 0     5453.069999             3.333333  2020-09-19T08:40:49.0
# 1             NaN                  NaN  2023-08-25T05:47:41.0
# 2             NaN                  NaN  2023-08-25T05:47:41.0
# 3             NaN                  NaN  2023-08-25T05:47:42.0
# 4             NaN                  NaN  2023-08-25T05:47:42.0
#
#               updateDate  hasTurnDetectionDisabled
# 0  2020-09-19T08:44:37.0                     False
# 1  2023-08-25T05:47:41.0                     False
# 2  2023-08-25T05:47:41.0                     False
# 3  2023-08-25T05:47:42.0                     False
# 4  2023-08-26T11:19:23.0                     False
# DataFrame for lenka@otap.dk_courses_1710413660638.json:
#                     courseName accessControl  elevationGainMeter  \
# 0         Kopi af Brøndby, syd        public               73.62
# 1  Mammutmarch 30km route 2022       private              244.31
# 2            MM 100 2022 Lenka       private              619.63
# 3             MM 55 2023 Lenka       private              405.76
# 4            MM 100 2023 Lenka       private              657.61
#
#    elevationLossMeter                                         startPoint  \
# 0               73.51  {'latitude': 55.65210342407227, 'longitude': 1...
# 1              244.31  {'latitude': 55.770299, 'longitude': 12.453361...
# 2              619.75  {'latitude': 55.847935, 'longitude': 12.571158...
# 3              403.68  {'latitude': 55.774839, 'longitude': 12.439693...
# 4              657.54  {'latitude': 55.847935, 'longitude': 12.571158...
#
#                                            geoPoints courseType  \
# 0  [{'latitude': 55.652103340253234, 'longitude':...    running
# 1  [{'latitude': 55.77029898762703, 'longitude': ...     hiking
# 2  [{'latitude': 55.84793494082987, 'longitude': ...     hiking
# 3  [{'latitude': 55.77483896166086, 'longitude': ...     hiking
# 4  [{'latitude': 55.84793494082987, 'longitude': ...     hiking
#
#    elapsedSeconds  speedMeterPerSecond             createDate  \
# 0     5453.069999             3.333333  2020-09-19T08:40:49.0
# 1             NaN                  NaN  2023-08-25T05:47:41.0
# 2             NaN                  NaN  2023-08-25T05:47:41.0
# 3             NaN                  NaN  2023-08-25T05:47:42.0
# 4             NaN                  NaN  2023-08-25T05:47:42.0
#
#               updateDate  hasTurnDetectionDisabled
# 0  2020-09-19T08:44:37.0                     False
# 1  2023-08-25T05:47:41.0                     False
# 2  2023-08-25T05:47:41.0                     False
# 3  2023-08-25T05:47:42.0                     False
# 4  2023-08-26T11:19:23.0                     False

# %%
# %matplotlib inline
import pandas as pd
import os
import json
from IPython.display import display

pd.set_option('display.max_columns', None)

# The corrected path
garmin_base_dir = "../files/Garmin_20241403"
di_connect_path = os.path.join(garmin_base_dir, "DI_CONNECT", "DI-Connect-Aggregator")  # Correcting the folder name

# Adjusting the function to store each JSON as a separate DataFrame
def find_json(path):
    dfs = {}  # Dictionary to hold DataFrames
    for root, dirs, files in os.walk(path):
        for file in files:
            if file.endswith('.json') & file.startswith('UDS'):
                full_path = os.path.join(root, file)
                with open(full_path, 'r') as f:
                    data = json.load(f)

                # Checking if the JSON is a list of dictionaries
                if isinstance(data, list) and all(isinstance(item, dict) for item in data):
                    df = pd.DataFrame(data)
                elif isinstance(data, dict):
                    # For a single dictionary, we still convert it into a DataFrame
                    df = pd.DataFrame([data])
                else:
                    # If the structure is different, we might need to adjust the approach
                    print(f"Unexpected JSON structure in {file}")
                    continue

                # Storing the DataFrame in the dictionary with the filename as key
                dfs[file] = df

                # Displaying the DataFrame's first few rows
                print(f"DataFrame for {os.path.basename(file)} loaded.")
                #display(dfs[file].head())

    return dfs

dfs = find_json(di_connect_path)

len(dfs)

#dfs['UDSFile_2022-07-24_2022-11-01.json'].head()


#dfs['UDSFile_2022-07-24_2022-11-01.json'][['calendarDate', 'totalKilocalories', 'activeKilocalories', 'restingCaloriesFromActivity', 'totalSteps', 'moderateIntensityMinutes', 'vigorousIntensityMinutes', 'userIntensityMinutesGoal', 'minHeartRate', 'maxHeartRate', 'restingHeartRate','minAvgHeartRate','maxAvgHeartRate','allDayStress','bodyBattery']]
dfs['UDSFile_2022-07-24_2022-11-01.json'].at[0,'allDayStress']
#dfs['UDSFile_2022-07-24_2022-11-01.json'].at[0,'bodyBattery']
# Out:
# DataFrame for UDSFile_2012-09-14_2012-12-23.json loaded.
# DataFrame for UDSFile_2011-05-03_2011-08-11.json loaded.
# DataFrame for UDSFile_2011-08-11_2011-11-19.json loaded.
# DataFrame for UDSFile_2022-07-24_2022-11-01.json loaded.
# DataFrame for UDSFile_2022-11-01_2023-02-09.json loaded.
# DataFrame for UDSFile_2023-08-28_2023-12-06.json loaded.
# DataFrame for UDSFile_2005-11-10_2006-02-18.json loaded.
# DataFrame for UDSFile_2014-08-15_2014-11-23.json loaded.
# DataFrame for UDSFile_2014-01-27_2014-05-07.json loaded.
# DataFrame for UDSFile_2021-09-27_2022-01-05.json loaded.
# DataFrame for UDSFile_2013-07-11_2013-10-19.json loaded.
# DataFrame for UDSFile_2022-01-05_2022-04-15.json loaded.
# DataFrame for UDSFile_2021-03-11_2021-06-19.json loaded.
# DataFrame for UDSFile_2022-04-15_2022-07-24.json loaded.
# DataFrame for UDSFile_2023-12-06_2024-03-15.json loaded.
# DataFrame for UDSFile_2020-05-15_2020-08-23.json loaded.
# DataFrame for UDSFile_2023-05-20_2023-08-28.json loaded.
# DataFrame for UDSFile_2021-06-19_2021-09-27.json loaded.
# DataFrame for UDSFile_2014-05-07_2014-08-15.json loaded.
# DataFrame for UDSFile_2020-12-01_2021-03-11.json loaded.
# DataFrame for UDSFile_2023-02-09_2023-05-20.json loaded.
# DataFrame for UDSFile_2020-08-23_2020-12-01.json loaded.
# {'userProfilePK': 86607424,
#  'calendarDate': '2022-07-24',
#  'aggregatorList': [{'type': 'TOTAL',
#    'averageStressLevel': 23,
#    'averageStressLevelIntensity': 20,
#    'maxStressLevel': 100,
#    'stressIntensityCount': 909,
#    'stressOffWristCount': 123,
#    'stressTooActiveCount': 404,
#    'totalStressCount': 1436,
#    'totalStressIntensity': 20272,
#    'stressDuration': 15120,
#    'restDuration': 39420,
#    'activityDuration': 24240,
#    'uncategorizedDuration': 7380,
#    'totalDuration': 86160,
#    'lowDuration': 11340,
#    'mediumDuration': 3000,
#    'highDuration': 780},
#   {'type': 'AWAKE',
#    'averageStressLevel': 33,
#    'averageStressLevelIntensity': 28,
#    'maxStressLevel': 100,
#    'stressIntensityCount': 351,
#    'stressOffWristCount': 120,
#    'stressTooActiveCount': 389,
#    'totalStressCount': 860,
#    'totalStressIntensity': -1456,
#    'stressDuration': 11280,
#    'restDuration': 9780,
#    'activityDuration': 23340,
#    'uncategorizedDuration': 7200,
#    'totalDuration': 51600,
#    'lowDuration': 7740,
#    'mediumDuration': 2820,
#    'highDuration': 720},
#   {'type': 'ASLEEP',
#    'averageStressLevel': 16,
#    'averageStressLevelIntensity': 16,
#    'maxStressLevel': 78,
#    'stressIntensityCount': 558,
#    'stressOffWristCount': 3,
#    'stressTooActiveCount': 15,
#    'totalStressCount': 576,
#    'totalStressIntensity': 21728,
#    'stressDuration': 3840,
#    'restDuration': 29640,
#    'activityDuration': 900,
#    'uncategorizedDuration': 180,
#    'totalDuration': 34560,
#    'lowDuration': 3600,
#    'mediumDuration': 180,
#    'highDuration': 60}]}

# %%
# %matplotlib inline
import pandas as pd
import os
import json
from IPython.display import display

pd.set_option('display.max_columns', None)

# The corrected path
garmin_base_dir = "../files/Garmin_20241403"
di_connect_path = os.path.join(garmin_base_dir, "DI_CONNECT", "DI-Connect-Aggregator")  # Correcting the folder name

# Adjusting the function to combine all JSON data into one DataFrame
def find_and_combine_json(path):
    all_dfs = []  # List to hold all DataFrames
    for root, dirs, files in os.walk(path):
        for file in sorted(files):  # Sort files alphabetically to align with date order if possible
            if file.endswith('.json') and file.startswith('UDS'):
                full_path = os.path.join(root, file)
                with open(full_path, 'r') as f:
                    data = json.load(f)

                # Convert JSON data into a DataFrame
                if isinstance(data, list) and all(isinstance(item, dict) for item in data):
                    df = pd.DataFrame(data)
                elif isinstance(data, dict):
                    df = pd.DataFrame([data])
                else:
                    print(f"Unexpected JSON structure in {file}")
                    continue

                all_dfs.append(df)  # Append the DataFrame to the list

    if all_dfs:
        # Combine all DataFrames into one
        combined_df = pd.concat(all_dfs, ignore_index=True)
        # Assuming 'calendarDate' exists and is the correct key for sorting by date
        combined_df['calendarDate'] = pd.to_datetime(combined_df['calendarDate'])
        combined_df.sort_values('calendarDate', inplace=True)
        return combined_df
    else:
        return None

# Combine all JSON data into a single DataFrame
combined_df = find_and_combine_json(di_connect_path)

if combined_df is not None:
    print("Combined DataFrame loaded with {} entries.".format(len(combined_df)))
#    display(combined_df.head())
else:
    print("No data was loaded. Please check the file paths and JSON structures.")

focus_df = combined_df[['calendarDate', 'totalKilocalories', 'activeKilocalories', 'restingCaloriesFromActivity', 
                        'totalSteps', 'moderateIntensityMinutes', 'vigorousIntensityMinutes', 'userIntensityMinutesGoal', 
                        'minHeartRate', 'maxHeartRate', 'restingHeartRate','minAvgHeartRate','maxAvgHeartRate',
                        'allDayStress','bodyBattery']]

focus_df = focus_df[focus_df['calendarDate'].dt.year >= 2020]
focus_df.head(5)
# Out:
# Combined DataFrame loaded with 1379 entries.
#    calendarDate  totalKilocalories  activeKilocalories  \
# 14   2020-06-18             1923.0               446.0
# 15   2020-06-19             1885.0               408.0
# 16   2020-06-20             2456.0               975.0
# 17   2020-06-21             2202.0               734.0
# 18   2020-06-22             2017.0               549.0
#
#     restingCaloriesFromActivity  totalSteps  moderateIntensityMinutes  \
# 14                          NaN     13987.0                      11.0
# 15                          NaN     12455.0                       2.0
# 16                          NaN     26379.0                      20.0
# 17                          NaN     12401.0                      52.0
# 18                          NaN     15256.0                       5.0
#
#     vigorousIntensityMinutes  userIntensityMinutesGoal  minHeartRate  \
# 14                       0.0                     180.0          64.0
# 15                      10.0                     180.0          55.0
# 16                      88.0                     180.0          53.0
# 17                       4.0                     180.0          50.0
# 18                      43.0                     180.0          53.0
#
#     maxHeartRate  restingHeartRate  minAvgHeartRate  maxAvgHeartRate  \
# 14         128.0              68.0             65.0            121.0
# 15         160.0              64.0             56.0            158.0
# 16         159.0              62.0             54.0            156.0
# 17         139.0              60.0             52.0            134.0
# 18         152.0              60.0             54.0            149.0
#
#                                          allDayStress  \
# 14  {'userProfilePK': 86607424, 'calendarDate': '2...
# 15  {'userProfilePK': 86607424, 'calendarDate': '2...
# 16  {'userProfilePK': 86607424, 'calendarDate': '2...
# 17  {'userProfilePK': 86607424, 'calendarDate': '2...
# 18  {'userProfilePK': 86607424, 'calendarDate': '2...
#
#                                           bodyBattery
# 14  {'userProfilePK': 86607424, 'calendarDate': '2...
# 15  {'userProfilePK': 86607424, 'calendarDate': '2...
# 16  {'userProfilePK': 86607424, 'calendarDate': '2...
# 17  {'userProfilePK': 86607424, 'calendarDate': '2...
# 18  {'userProfilePK': 86607424, 'calendarDate': '2...

# %%
focus_df[['allDayStress']].iat[0,0]['aggregatorList']
#focus_df[['bodyBattery']].iat[0,0]['bodyBatteryStatList']
# Out:
# [{'type': 'TOTAL',
#   'averageStressLevel': 40,
#   'averageStressLevelIntensity': 35,
#   'maxStressLevel': 93,
#   'stressIntensityCount': 376,
#   'stressOffWristCount': 148,
#   'stressTooActiveCount': 253,
#   'totalStressCount': 777,
#   'totalStressIntensity': -5086,
#   'stressDuration': 15480,
#   'restDuration': 7080,
#   'activityDuration': 15180,
#   'uncategorizedDuration': 8880,
#   'totalDuration': 46620,
#   'lowDuration': 7680,
#   'mediumDuration': 7020,
#   'highDuration': 780},
#  {'type': 'AWAKE',
#   'averageStressLevel': 40,
#   'averageStressLevelIntensity': 35,
#   'maxStressLevel': 93,
#   'stressIntensityCount': 369,
#   'stressOffWristCount': 119,
#   'stressTooActiveCount': 253,
#   'totalStressCount': 741,
#   'totalStressIntensity': -5035,
#   'stressDuration': 15120,
#   'restDuration': 7020,
#   'activityDuration': 15180,
#   'uncategorizedDuration': 7140,
#   'totalDuration': 44460,
#   'lowDuration': 7320,
#   'mediumDuration': 7020,
#   'highDuration': 780},
#  {'type': 'ASLEEP',
#   'averageStressLevel': 31,
#   'averageStressLevelIntensity': 30,
#   'maxStressLevel': 48,
#   'stressIntensityCount': 7,
#   'stressOffWristCount': 29,
#   'stressTooActiveCount': 0,
#   'totalStressCount': 36,
#   'totalStressIntensity': -51,
#   'stressDuration': 360,
#   'restDuration': 60,
#   'activityDuration': 0,
#   'uncategorizedDuration': 1740,
#   'totalDuration': 2160,
#   'lowDuration': 360,
#   'mediumDuration': 0,
#   'highDuration': 0}]

# %% [markdown]
# ## GARMIN RUNNING HEATMAP

# %% [markdown]
# <!-- import requests
#
# my_client_id = "18a3b276-54d8-4f8b-a5fd-d0090b04a810"
# my_client_secret = "MEHn2fe22ZIyJbSujpSztjK25xP5B0VYeec"
#
# # Assuming Garmin has a straightforward OAuth2 flow (check documentation for exact steps)
# def get_access_token(client_id, client_secret):
#     #auth_url = 'https://connectapi.garmin.com/oauth2/token'
#     auth_url = 'https://seminmis.dk'
#     response = requests.post(auth_url, data={
#         'grant_type': 'client_credentials',
#         'client_id': client_id,
#         'client_secret': client_secret,
#     })
#     response_data = response.json()
#     return response_data['access_token']
#
# def fetch_activities(access_token):
#     activities_url = 'https://connectapi.garmin.com/activities'
#     headers = {'Authorization': f'Bearer {access_token}'}
#     response = requests.get(activities_url, headers=headers)
#     activities = response.json()
#     return activities  # This will be a list or dict depending on API
#
# def download_gpx(activity_id, access_token):
#     gpx_url = f'https://connectapi.garmin.com/activities/{activity_id}/gpx'
#     headers = {'Authorization': f'Bearer {access_token}'}
#     response = requests.get(gpx_url, headers=headers)
#     gpx_data = response.content  # GPX data as bytes
#     with open(f'{activity_id}.gpx', 'wb') as f:
#         f.write(gpx_data)
#
# # Replace 'your_client_id' and 'your_client_secret' with your actual Garmin API credentials
# access_token = get_access_token(my_client_id, my_client_secret)
# activities = fetch_activities(access_token)
#
# for activity in activities:  # You may need to adjust depending on the structure of activities
#     activity_id = activity['id']  # Assuming 'id' is part of the activity structure
#     download_gpx(activity_id, access_token)
# -->

# %% [markdown]
# ## CATS AND THE CITY

# %%
import os
from PIL import Image
from PIL.ExifTags import TAGS, GPSTAGS
import pandas as pd

def get_decimal_from_dms(dms, ref):
    degrees = dms[0]
    minutes = dms[1] / 60.0
    seconds = dms[2] / 3600.0

    if ref in ['S', 'W']:
        degrees = -degrees
        minutes = -minutes
        seconds = -seconds

    return degrees + minutes + seconds

def extract_gps_info(image_path):
    try:
        image = Image.open(image_path)
        exif_data = {TAGS[key]: value for key, value in image._getexif().items() if key in TAGS and type(value) is not bytes}

        if 'GPSInfo' in exif_data:
            gps_info = {GPSTAGS.get(key, key): value for key, value in exif_data['GPSInfo'].items()}
            lat = get_decimal_from_dms(gps_info['GPSLatitude'], gps_info['GPSLatitudeRef'])
            lon = get_decimal_from_dms(gps_info['GPSLongitude'], gps_info['GPSLongitudeRef'])
            return lat, lon
        else:
            print("HERE")
            return None, None
    except:
        return None, None

def process_folder(folder_path):
    data = {'Filename': [], 'Latitude': [], 'Longitude': [], 'ImagePath': []}
    for filename in os.listdir(folder_path):
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.heic')):
    #            print(filename)
            lat, lon = extract_gps_info(os.path.join(folder_path, filename))
            if lat is not None and lon is not None:
                data['Filename'].append(filename)
                data['Latitude'].append(lat)
                data['Longitude'].append(lon)
                # Assuming thumbnails are stored in a parallel structure or with a naming convention
                data['ImagePath'].append(filename)
            else:
                 print("No GPS data found")
    return pd.DataFrame(data)

# Specify your folder path here
folder_path = '../files/catimg/'
df = process_folder(folder_path)

# To save the DataFrame to a CSV file
df.to_csv('geodata.csv', index=False)

df
# Out:
#           Filename   Latitude  Longitude      ImagePath
# 0    IMG_2399.jpeg  55.703536  12.521419  IMG_2399.jpeg
# 1    IMG_3731.jpeg  55.717647  12.495931  IMG_3731.jpeg
# 2    IMG_3789.jpeg  55.648728  12.604731  IMG_3789.jpeg
# 3    IMG_3459.jpeg  55.623853  12.573617  IMG_3459.jpeg
# 4    IMG_1608.jpeg  55.135456  15.140861  IMG_1608.jpeg
# ..             ...        ...        ...            ...
# 100  IMG_7073.jpeg  55.740422  12.459467  IMG_7073.jpeg
# 101  IMG_3175.jpeg  55.730072  12.523000  IMG_3175.jpeg
# 102  IMG_2461.jpeg  55.702775  12.523586  IMG_2461.jpeg
# 103  IMG_7049.jpeg  55.713903  12.488917  IMG_7049.jpeg
# 104  IMG_0558.jpeg  55.792183  12.492497  IMG_0558.jpeg
#
# [105 rows x 4 columns]

# %%
import folium

# Assuming 'df' is your DataFrame with the latitude and longitude

# Create a map centered around the average location in your DataFrame
map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

# Add markers for each image location
for idx, row in df.iterrows():
    folium.Marker([row['Latitude'], row['Longitude']],
                  popup=f"Filename: {row['Filename']}").add_to(m)

# Display the map in Jupyter Notebook
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6c9861193e444a34b805a3b10b30564 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6c9861193e444a34b805a3b10b30564&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6c9861193e444a34b805a3b10b30564 = L.map(
#                 &quot;map_b6c9861193e444a34b805a3b10b30564&quot;,
#                 {
#                     center: [55.657945026455025, 12.507787962962963],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3504500e1d06dad58f27275d0cb21ec8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_3504500e1d06dad58f27275d0cb21ec8.addTo(map_b6c9861193e444a34b805a3b10b30564);
#
#
#             var marker_7662bf489bd8e5d41524f1e632998b3f = L.marker(
#                 [55.70353611111111, 12.521419444444446],
#                 {}
#             ).addTo(map_b6c9861193e444a34b805a3b10b30564);
#
#
#         var popup_622e628eb4fedd0e7ae1254e60173f4d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9dd61df0383261fdd6e827e62e65e953 = $(`&lt;div id=&quot;html_9dd61df0383261fdd6e827e62e65e953&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Filename: IMG_2399.jpeg&lt;/div&gt;`)[0];
#                 popup_622e628eb4fedd0e7ae1254e60173f4d.setContent(html_9dd61df0383261fdd6e827e62e65e953);
#
#
#
#         marker_7662bf489bd8e5d41524f1e632998b3f.bindPopup(popup_622e628eb4fedd0e7ae1254e60173f4d)
#         ;
#
#
#
#
#             var marker_009f441a4e63d0d38f1110eb7f3fc046 = L.marker(
#                 [55.717647222222226, 12.495930555555555],
#                 {}
#             ).addTo(map_b6c9861193e444a34b805a3b10b30564);
#
#
#         var popup_bd4a9d278170e0ee158f11fa478a5905 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_561c9d04547895d94ce86882e2cd78e6 = $(`&lt;div id=&quot;html_561c9d04547895d94ce86882e2cd78e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Filename: IMG_3731.jpeg&lt;/div&gt;`)[0];
#                 popup_bd4a9d278170e0ee158f11fa478a5905.setContent(html_561c9d04547895d94ce86882e2cd78e6);
#
#
#
#         marker_009f441a4e63d0d38f1110eb7f3fc046.bindPopup(popup_bd4a9d278170e0ee158f11fa478a5905)
#         ;
#
#
#
#
#             var marker_b5794cde717e4bf00e2850516446f8cf = L.marker(
#                 [55.64872777777778, 12.604730555555555],
#                 {}
#             ).addTo(map_b6c9861193e444a34b805a3b10b30564);
#
#
#         var popup_4e6384c3815848936c84efb96f94634e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cf37cceeeb9ea4501d4bbebcf5833617 = $(`&lt;div id=&quot;html_cf37cceeeb9ea4501d4bbebcf5833617&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Filename: IMG_3789.jpeg&lt;/div&gt;`)[0];
#                 popup_4e6384c3815848936c84efb96f94634e.setContent(html_cf37cceeeb9ea4501d4bbebcf5833617);
#
#
#
#         marker_b5794cde717e4bf00e2850516446f8cf.bindPopup(popup_4e6384c3815848936c84efb96f94634e)
#         ;
#
#
#
#
#             var marker_553781bf79515bc1051ef7e64103b836 = L.marker(
#                 [55.62385277777778, 12.573616666666666],
#                 {}
#             ).addTo(map_b6c9861193e444a34b805a3b10b30564);
#
#
#         var popup_8a4a548731654ae2132cae8bc66f1ace = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3007c548d48785ef4d4850b2cf6df9ff = $(`&lt;div id=&quot;html_3007c548d48785ef4d4850b2cf6df9ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Filename: IMG_3459.jpeg&lt;/div&gt;`)[0];
#                 popup_8a4a548731654ae2132cae8bc66f1ace.setContent(html_3007c548d48785ef4d4850b2cf6df9ff);
#
#
#
#         marker_553781bf79515bc1051ef7e64103b836.bindPopup(popup_8a4a548731654ae2132cae8bc66f1ace)
#         ;
#
#
#
#
#             var marker_91a35908560ebbc43865ee26499901a5 = L.marker(
#                 [55.13545555555555, 15.14086111111111],
#                 {}
#             ).addTo(map_b6c9861193e444a34b805a3b10b30564);
#
#
#         var popup_b757097fcb135a4a95b6fc67d5749113 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_70a874987ad5ebc407f8181fe28d6f55 = $(`&lt;div id=&quot;html_70a874987ad5ebc407f8181fe28d6f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Filename: IMG_1608.jpeg&lt;/div&gt;`)[0];
#                 popup_b757097fcb135a4a95b6fc67d5749113.setContent(html_70a874987ad5ebc407f8181fe28d6f55);
#
#
#
#         marker_91a35908560ebbc43865ee26499901a5.bindPopup(popup_b757097fcb135a4a95b6fc67d5749113)
#         ;
#
#
#
#
#             var marker_fffe21ad89f0f6d9

# %%
import folium
from folium import IFrame

# Your modified DataFrame now includes 'ImagePath'

map_center = [df['Latitude'].mean(), df['Longitude'].mean()]
m = folium.Map(location=map_center, zoom_start=12)

for idx, row in df.iterrows():
    # Adjust image path as necessary to point to the correct location; might need adjustments if using a notebook
    image_path =  row['ImagePath']
    iframe = IFrame(f'<img src="{folder_path}{image_path}" width="150" height="100">', width=200, height=150)
    popup = folium.Popup(iframe, max_width=300)
    folium.Marker([row['Latitude'], row['Longitude']], popup=popup).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96ca56e1a19dd94298a0955f2dfe4c61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96ca56e1a19dd94298a0955f2dfe4c61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96ca56e1a19dd94298a0955f2dfe4c61 = L.map(
#                 &quot;map_96ca56e1a19dd94298a0955f2dfe4c61&quot;,
#                 {
#                     center: [55.657945026455025, 12.507787962962963],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7298d3e600d3b26fc7d723307f205606 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_7298d3e600d3b26fc7d723307f205606.addTo(map_96ca56e1a19dd94298a0955f2dfe4c61);
#
#
#             var marker_3284a049a94e1f791af241b3bf101e21 = L.marker(
#                 [55.70353611111111, 12.521419444444446],
#                 {}
#             ).addTo(map_96ca56e1a19dd94298a0955f2dfe4c61);
#
#
#         var popup_818b679399be4003bc071510447ca316 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_51a95eebd7181cc3537a842dd5676530 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8aW1nIHNyYz0iLi4vZmlsZXMvY2F0aW1nL0lNR18yMzk5LmpwZWciIHdpZHRoPSIxNTAiIGhlaWdodD0iMTAwIj4=&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_818b679399be4003bc071510447ca316.setContent(i_frame_51a95eebd7181cc3537a842dd5676530);
#
#
#
#         marker_3284a049a94e1f791af241b3bf101e21.bindPopup(popup_818b679399be4003bc071510447ca316)
#         ;
#
#
#
#
#             var marker_3ce6dd8702574ee810bc2f5ae70a3cf3 = L.marker(
#                 [55.717647222222226, 12.495930555555555],
#                 {}
#             ).addTo(map_96ca56e1a19dd94298a0955f2dfe4c61);
#
#
#         var popup_5fb58b14178c05c912a6a0e622662741 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_8d373e8a67c3a4a26f184feaf6a0d7c4 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8aW1nIHNyYz0iLi4vZmlsZXMvY2F0aW1nL0lNR18zNzMxLmpwZWciIHdpZHRoPSIxNTAiIGhlaWdodD0iMTAwIj4=&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_5fb58b14178c05c912a6a0e622662741.setContent(i_frame_8d373e8a67c3a4a26f184feaf6a0d7c4);
#
#
#
#         marker_3ce6dd8702574ee810bc2f5ae70a3cf3.bindPopup(popup_5fb58b14178c05c912a6a0e622662741)
#         ;
#
#
#
#
#             var marker_262413b8ea84c5ca6ef360417a7ecb27 = L.marker(
#                 [55.64872777777778, 12.604730555555555],
#                 {}
#             ).addTo(map_96ca56e1a19dd94298a0955f2dfe4c61);
#
#
#         var popup_1f889f3133c173d56e303108c18152e5 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_07a8f8d5fd5dcafe61b4821c876c06a5 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8aW1nIHNyYz0iLi4vZmlsZXMvY2F0aW1nL0lNR18zNzg5LmpwZWciIHdpZHRoPSIxNTAiIGhlaWdodD0iMTAwIj4=&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_1f889f3133c173d56e303108c18152e5.setContent(i_frame_07a8f8d5fd5dcafe61b4821c876c06a5);
#
#
#
#         marker_262413b8ea84c5ca6ef360417a7ecb27.bindPopup(popup_1f889f3133c173d56e303108c18152e5)
#         ;
#
#
#
#
#             var marker_93b6e2559abaa36a026d0441e89566e4 = L.marker(
#                 [55.62385277777778, 12.573616666666666],
#                 {}
#             ).addTo(map_96ca56e1a19dd94298a0955f2dfe4c61);
#
#
#         var popup_67a7bbedc1be25bbef032c6291222dbc = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_d7ac27d092be26f5d8beea65a6f0c465 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICA8aW1nIHNyYz0iLi4vZmlsZXMvY2F0aW1nL0lNR18zNDU5LmpwZWciIHdpZHRoPSIxNTAiIGhlaWdodD0iMTAwIj4=&quot; width=&quot;200&quot; style=&quot;border:none !important;&quot; height=&quot;150&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_67a7bbedc1be25bbef032c6291222dbc.setContent(i_frame_d7ac27d092be26f5d8beea65a6f0c465);
#
#
#
#         marker_93b6e2559abaa36a026d0441e89566e4.bindPopup(popup_67a7bbedc1be25bbef032c6291222dbc)
#         ;
#
#
#
#
#             var marker_44a626adefbe67787c2ea919205f55d9 = L.marker(
#                 [55.13545555555555, 15.14086111111111],
#                 {}
#             ).addTo(map_96ca56e1a19dd94298a0955f2dfe4c61);
#
#
#         var popup_35a6109c698f7e17dd50e2250b6f692e = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var i_frame_1738fa1afd81102abb68fcf15d2e844d = $(`&lt;iframe src=&quot;
